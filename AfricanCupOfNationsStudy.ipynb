# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/SoccerCompetitionsStudy/blob/main/AfricanCupOfNationsStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, FFMpegWriter
import seaborn as sns

# %%
# Importing the dataset:
nt_tournaments = pd.ExcelFile('NT_tournaments_finals.xlsx')
ac = pd.read_excel(nt_tournaments, 'African Cup of Nations finals')

# Displaying the last 5 champions:
ac.tail()
# Out:
#     Year       Winners Score Runners-up                        Venue  \
# 29  2015  Ivory Coast    0–0      Ghana              Estadio de Bata
# 30  2017     Cameroon    2–1      Egypt            Stade de l'Amitié
# 31  2019      Algeria    1–0    Senegal  Cairo International Stadium
# 32  2021      Senegal    0–0      Egypt               Olembe Stadium
# 33  2023           NaN   NaN        NaN    Alassane Ouattara Stadium
#
#      Host City       Host Country  Attendance            How the match was won
# 29        Bata  Equatorial Guinea     32857.0  Extra time and Penalty shootout
# 30  Libreville              Gabon     38250.0                     Regular time
# 31       Cairo              Egypt     75000.0                     Regular time
# 32     Yaoundé           Cameroon     48000.0  Extra time and Penalty shootout
# 33     Abidjan        Ivory Coast         NaN                              NaN

# %%
# Displaying the number of rows and columns in the dataset:
ac.shape
# Out:
# (34, 9)

# %%
# Displaying the datatypes presented in the columns:
ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   34 non-null     int64
#  1   Winners                33 non-null     object
#  2   Score                  33 non-null     object
#  3   Runners-up             33 non-null     object
#  4   Venue                  34 non-null     object
#  5   Host City              34 non-null     object
#  6   Host Country           34 non-null     object
#  7   Attendance             33 non-null     float64
#  8   How the match was won  33 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.5+ KB

# %%
# Displaying number of titles by nation:
ac.groupby('Year').first()['Winners'].value_counts().plot(kind = 'barh', color = 'gold')
plt.ylabel(None)
plt.title('Winners by Nation', fontweight = 'bold')
plt.show()

# %%
# Displaying number of runners-up by nation:
ac.groupby('Year').first()['Runners-up'].value_counts().plot(kind = 'barh', color = 'silver')
plt.ylabel(None)
plt.title('Runners-up by Nation', fontweight = 'bold')
plt.show()

# %%
# Displaying host countries by nation:
ac.groupby('Year').first()['Host Country'].value_counts().plot(kind = 'barh', color = 'lime')
plt.ylabel(None)
plt.title('Host Countries by Nation', fontweight = 'bold')
plt.show()

# %%
# Displaying host cities that hosted finals:
ac.groupby('Year').first()['Host City'].value_counts().plot(kind = 'barh', color = 'lime')
plt.ylabel(None)
plt.title('Host Cities', fontweight = 'bold')
plt.show()

# %%
# Displaying venues that hosted finals:
ac.groupby('Year').first()['Venue'].value_counts().plot(kind = 'barh', color = 'magenta')
plt.ylabel(None)
plt.title('Venues', fontweight = 'bold')
plt.show()

# %%
# Displaying the attendances by year:
plt.title('Attendances by Year', fontweight = 'bold')
plt.plot(ac['Year'], ac['Attendance'], color = 'orange')
plt.show()

# %%
# Displaying the distribution of the way the match was won:
ac.groupby('Year').first()['How the match was won'].value_counts().plot(kind = 'pie')
plt.ylabel(None)
plt.title('How the matches were won', fontweight = 'bold')
plt.show()
