# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/SoccerCompetitionsStudy/blob/main/AfricanCupOfNationsStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style = 'whitegrid')
plt.style.use('seaborn-pastel')
# Out:
# <ipython-input-1-de0a920cb73a>:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %%
# Importing the dataset:
nt_tournaments = pd.ExcelFile('NT_tournaments_finals.xlsx')
ac = pd.read_excel(nt_tournaments, 'Africa Cup of Nations finals')

# Displaying the last 5 champions:
ac.tail()
# Out:
#     Year       Winners Score Runners-up                        Venue  \
# 29  2015  Ivory Coast    0–0      Ghana              Estadio de Bata
# 30  2017     Cameroon    2–1      Egypt            Stade de l'Amitié
# 31  2019      Algeria    1–0    Senegal  Cairo International Stadium
# 32  2021      Senegal    0–0      Egypt               Olembe Stadium
# 33  2023  Ivory Coast    2–1   Nigeria     Alassane Ouattara Stadium
#
#      Host city       Host country  Attendance            How the match was won
# 29        Bata  Equatorial Guinea       32857  Extra time and Penalty shootout
# 30  Libreville              Gabon       38250                     Regular time
# 31       Cairo              Egypt       75000                     Regular time
# 32     Yaoundé           Cameroon       48000  Extra time and Penalty shootout
# 33     Abidjan        Ivory Coast       57094                     Regular time

# %%
# Displaying the number of rows and columns in the dataset:
ac.shape
# Out:
# (34, 9)

# %%
# Displaying the datatypes presented in the columns:
ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   34 non-null     int64
#  1   Winners                34 non-null     object
#  2   Score                  34 non-null     object
#  3   Runners-up             34 non-null     object
#  4   Venue                  34 non-null     object
#  5   Host city              34 non-null     object
#  6   Host country           34 non-null     object
#  7   Attendance             34 non-null     int64
#  8   How the match was won  34 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 2.5+ KB

# %%
# Displaying the number of titles by nation:
ac.groupby('Year').first()['Winners'].value_counts().plot(kind = 'barh', color = 'purple', figsize = (8, 8))
plt.ylabel(None)
plt.title('Winners', fontweight = 'bold')
plt.show()

# %%
# Displaying the number of runners-up by nation:
ac.groupby('Year').first()['Runners-up'].value_counts().plot(kind = 'barh', color = 'purple', figsize = (8, 8))
plt.ylabel(None)
plt.title('Runners-up', fontweight = 'bold')
plt.show()

# %%
# Displaying the host countries by nation:
ac.groupby('Year').first()['Host country'].value_counts().plot(kind = 'barh', color = 'purple', figsize = (8, 8))
plt.ylabel(None)
plt.title('Host Countries', fontweight = 'bold')
plt.show()

# %%
# Displaying the host cities that hosted finals:
ac.groupby('Year').first()['Host city'].value_counts().plot(kind = 'barh', color = 'purple', figsize = (8, 8))
plt.ylabel(None)
plt.title('Host Cities', fontweight = 'bold')
plt.show()

# %%
# Displaying the venues that hosted finals:
ac.groupby('Year').first()['Venue'].value_counts().plot(kind = 'barh', color = 'purple', figsize = (8, 8))
plt.ylabel(None)
plt.title('Venues', fontweight = 'bold')
plt.show()

# %%
# Displaying the attendances by year:
plt.title('Attendances', fontweight = 'bold')
plt.plot(ac['Year'], ac['Attendance'], color = 'purple')
plt.show()

# %%
# Displaying the distribution of the way the match was won:
ac.groupby('Year').first()['How the match was won'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('How the matches were won', fontweight = 'bold')
plt.show()
