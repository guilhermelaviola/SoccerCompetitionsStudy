# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/SoccerCompetitionsStudy/blob/main/UICStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from google.colab import drive
sns.set(style = 'darkgrid')
plt.style.use('seaborn-pastel')
drive.mount('/content/drive')
# Out:
# <ipython-input-1-921de9e8a408>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')
# Mounted at /content/drive

# %%
# Setting the search parameters
filename = 'uefa-competitions-finals.xlsx'
search_path = '/content/drive/My Drive/Datasets/Soccer'
# Search for the file
file = None
for root, dirs, files in os.walk(search_path):
    if filename in files:
        file= os.path.join(root, filename)
        break
    df = pd.read_excel(file)

# %%
# Importing the dataset:
uefa_competitions = pd.ExcelFile(file)
uic = pd.read_excel(uefa_competitions, 'UEFA Intertoto Cup finals')

# Displaying the last 5 champions:
uic.tail()
# Out:
#      Season  Year Winners country           Winners Score (1st leg)  \
# 65  2005-06  2006          France         Marseille             0–2
# 66  2005-06  2006         Germany      Hamburger SV             1–0
# 67  2006-07  2007         England  Newcastle United             1–1
# 68  2007-08  2008         Germany      Hamburger SV             1–1
# 69  2008-09  2009        Portugal             Braga             2–0
#
#    Score (2nd leg)           Runners-up Runners-up country  \
# 65             5–1  Deportivo La Coruña              Spain
# 66             0–0             Valencia              Spain
# 67             3–0           Lillestrøm             Norway
# 68             4–0       Dacia Chișinău            Moldova
# 69             3–0            Sivasspor             Turkey
#
#          Venue (1st leg)  Host city (1st leg) Host country (1st leg)  \
# 65                Riazor             A Coruña                  Spain
# ...

# %%
# Displaying the number of rows and columns in the dataset:
uic.shape
# Out:
# (70, 17)

# %%
# Displaying the datatypes presented in the columns:
uic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Season                  70 non-null     object
#  1   Year                    70 non-null     int64
#  2   Winners country         70 non-null     object
#  3   Winners                 70 non-null     object
#  4   Score (1st leg)         41 non-null     object
#  5   Score (2nd leg)         38 non-null     object
#  6   Runners-up              41 non-null     object
#  7   Runners-up country      41 non-null     object
#  8   Venue (1st leg)         41 non-null     object
#  9   Host city (1st leg)     41 non-null     object
#  10  Host country (1st leg)  41 non-null     object
#  11  Venue (2nd leg)         38 non-null     object
#  12  Host city (2nd leg)     38 non-null     object
#  13  Host country (2nd leg)  38 non-null     object
# ...

# %%
# Displaying number of titles by club:
uic['Winners'].value_counts().plot(kind = 'barh', color = 'lime', figsize = (8, 16))
plt.ylabel(None)
plt.title('Winners by Club', fontweight = 'bold')
plt.show()

# %%
# Displaying number of runners-up by club:
uic['Runners-up'].value_counts().plot(kind = 'barh', color = 'lime', figsize = (8, 12))
plt.ylabel(None)
plt.title('Runners-up by Club', fontweight = 'bold')
plt.show()

# %%
# Displaying number of titles by country:
uic['Winners country'].value_counts().plot(kind = 'barh', color = 'lime', figsize = (8, 4))
plt.ylabel(None)
plt.title('Winners by Country', fontweight = 'bold')
plt.show()

# %%
# Displaying number of runners-up by country:
uic['Runners-up country'].value_counts().plot(kind = 'barh', color = 'lime', figsize = (8, 6))
plt.ylabel(None)
plt.title('Runners-up by Country', fontweight = 'bold')
plt.show()

# %%
# Displaying distribution of venues that hosted finals (1st leg):
uic['Venue (1st leg)'].value_counts().plot(kind = 'barh',color = 'lime', figsize = (8, 12))
plt.ylabel(None)
plt.title('Venues that hosted finals (1st leg)', fontweight = 'bold')
plt.show()

# %%
# Displaying distribution of cities that hosted finals (1st leg):
uic['Host city (1st leg)'].value_counts().plot(kind = 'barh', color = 'lime', figsize = (8, 12))
plt.ylabel(None)
plt.title('Cities that hosted finals (1st leg)', fontweight = 'bold')
plt.show()

# %%
# Displaying distribution of cities that hosted finals (1st leg):
uic['Host country (1st leg)'].value_counts().plot(kind = 'barh', color = 'lime', figsize = (8, 4))
plt.ylabel(None)
plt.title('Countries that hosted finals (1st leg)', fontweight = 'bold')
plt.show()

# %%
# Displaying distribution of venues that hosted finals (2nd leg):
uic['Venue (2nd leg)'].value_counts().plot(kind = 'barh', color = 'lime', figsize = (8, 12))
plt.ylabel(None)
plt.title('Venues that hosted finals (2nd leg)', fontweight = 'bold')
plt.show()

# %%
# Displaying distribution of cities that hosted finals (2nd leg):
uic['Host city (2nd leg)'].value_counts().plot(kind = 'barh', color = 'lime', figsize = (8, 12))
plt.ylabel(None)
plt.title('Cities that hosted finals (2nd leg)', fontweight = 'bold')
plt.show()

# %%
# Checking if the club won UEL at home or away:
def champion_at_home(row):
  winners_country = row['Winners country']
  host_country = row['Host country (2nd leg)']
  if winners_country == host_country:
    result = 'Home'
  else:
    result = 'Away'
  return result

# Applying the function above on a column of the dataset and generating a new column as result:
uic['Home champion?'] = uic.apply(champion_at_home, axis=1)
uic.head()
# Out:
#     Season  Year Winners country                   Winners Score (1st leg)  \
# 0  1961-62  1962     Netherlands                      Ajax             4–2
# 1  1962-63  1963  Czech Republic          Inter Bratislava             1–0
# 2  1963-64  1964  Czech Republic          Inter Bratislava             1–0
# 3  1964-65  1965          Poland             Polonia Bytom             0–3
# 4  1965-66  1966         Germany  1. FC Lokomotive Leipzig             0–1
#
#   Score (2nd leg)      Runners-up Runners-up country  \
# 0             NaN       Feyenoord        Netherlands
# 1             NaN          Padova              Italy
# 2             NaN   Polonia Bytom             Poland
# 3             5–1      SC Leipzig            Germany
# 4             4–0  IFK Norrköping             Sweden
#
#                Venue (1st leg) Host city (1st leg) Host country (1st leg)  \
# 0  Olympisch Stadion Amsterdam           Amsterdam            Netherlands
# ...

# %%
# Displaying the clubs who were champions at home and away:
uic['Home champion?'].value_counts().plot(kind = 'pie', autopct = '%.0f%%', figsize = (8, 8), wedgeprops = dict(width = 0.4), pctdistance = 0.8)
plt.ylabel(None)
plt.title('Champions at home and away', fontweight = 'bold')
plt.show()

# %%
# Displaying the attendances of the 1st and 2nd leg matches by season:
plt.figure(figsize = (8, 4))
plt.title('Attendances of the 1st and 2nd leg matches by season', fontweight = 'bold')
plt.plot(uic['Year'], uic['Attendance (1st leg)'])
plt.plot(uic['Year'], uic['Attendance (2nd leg)'])
plt.show()

# %%
# Displaying the total attendances (1st and 2nd leg matches) by season:
plt.figure(figsize = (8, 4))
plt.title('Total attendances of the 1st and 2nd leg matches by season', fontweight = 'bold')
plt.plot(uic['Year'], uic['Attendance (1st leg)'] + uic['Attendance (2nd leg)'])

# %%
# Displaying the average attendances (1st and 2nd leg matches) by season:
plt.figure(figsize = (8, 4))
plt.title('Average attendances of the 1st and 2nd leg matches by season', fontweight = 'bold')
plt.plot(uic['Year'], (uic['Attendance (1st leg)'] + uic['Attendance (2nd leg)']) / 2)
