# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/SoccerCompetitionsStudy/blob/main/SerieATIM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from google.colab import drive
sns.set(style = 'whitegrid')
plt.style.use('seaborn-pastel')
drive.mount('/content/drive')
# Out:
# <ipython-input-1-afcfcec3bb98>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')
# Mounted at /content/drive

# %%
# Setting the search parameters
filename = 'italian-football.xlsx'
search_path = '/content/drive/My Drive/Datasets/Soccer'
# Search for the file
file = None
for root, dirs, files in os.walk(search_path):
    if filename in files:
        file= os.path.join(root, filename)
        break
    df = pd.read_excel(file)

# %%
# Importing the dataset:
italian_football = pd.ExcelFile(file)
sa = pd.read_excel(italian_football, 'Serie A TIM')

# Displaying the last 5 champions:
sa.tail()
# Out:
#       Season Competition name         Winners      Runners-up     Third Place  \
# 120  2019–20          Serie A        Juventus  Internazionale        Atalanta
# 121  2020–21          Serie A  Internazionale           Milan        Atalanta
# 122  2021–22          Serie A           Milan  Internazionale          Napoli
# 123  2022–23          Serie A          Napoli           Lazio  Internazionale
# 124  2023–24          Serie A  Internazionale           Milan        Juventus
#
#           Top scorer 1          Club 1  Number of goals 1    Top scorer 2  \
# 120      Ciro Immobile           Lazio               36.0             NaN
# 121  Cristiano Ronaldo        Juventus               29.0             NaN
# 122      Ciro Immobile           Lazio               27.0             NaN
# 123     Victor Osimhen          Napoli               26.0             NaN
# 124   Lautaro Martínez  Internazionale               24.0  Dusan Vlahovic
#
# ...

# %%
# Displaying the number of rows and columns in the dataset:
sa.shape
# Out:
# (125, 15)

# %%
# Displaying the datatypes presented in the columns:
sa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Season             125 non-null    object
#  1   Competition name   125 non-null    object
#  2   Winners            122 non-null    object
#  3   Runners-up         122 non-null    object
#  4   Third Place        113 non-null    object
#  5   Top scorer 1       122 non-null    object
#  6   Club 1             99 non-null     object
#  7   Number of goals 1  100 non-null    float64
#  8   Top scorer 2       10 non-null     object
#  9   Club 2             10 non-null     object
#  10  Number of goals 2  10 non-null     float64
#  11  Top scorer 3       2 non-null      object
#  12  Club 3             2 non-null      object
#  13  Number of goals 3  2 non-null      float64
#  14  How it was won     23 non-null     object
# dtypes: float64(3), object(12)
# ...

# %%
# Displaying statistical data of the numerical data present in the dataset:
sa.describe()
# Out:
#        Number of goals 1  Number of goals 2  Number of goals 3
# count         100.000000          10.000000           2.000000
# mean           23.940000          21.500000          16.000000
# std             6.106496           4.196559           1.414214
# min             0.000000          16.000000          15.000000
# 25%            21.000000          17.500000          15.500000
# 50%            24.000000          22.000000          16.000000
# 75%            28.000000          24.000000          16.500000
# max            36.000000          29.000000          17.000000

# %%
# Displaying number of titles by nation:
sa['Competition name'].value_counts().plot(kind = 'pie', figsize = (8, 8))
plt.ylabel(None)
plt.title('Competition name', fontweight = 'bold')
plt.show()

# %%
# Displaying winners:
sa['Winners'].value_counts().plot(kind = 'barh', color = 'cyan', figsize = (8, 6))
plt.ylabel(None)
plt.title('Winners', fontweight = 'bold')
plt.show()

# %%
# Displaying runners-up:
sa['Runners-up'].value_counts().plot(kind = 'barh', color = 'cyan', figsize = (8, 10))
plt.ylabel(None)
plt.title('Runners-up', fontweight = 'bold')
plt.show()

# %%
# Displaying winners:
sa['Third Place'].value_counts().plot(kind = 'barh', color = 'cyan', figsize = (8, 8))
plt.ylabel(None)
plt.title('Third Place', fontweight = 'bold')
plt.show()

# %%
# Displaying top scorers:
sa['Top scorer 1'].value_counts().plot(kind = 'barh', color = 'cyan', figsize = (8, 20))
plt.ylabel(None)
plt.title('Top scorers', fontweight = 'bold')
plt.show()

# %%
# Displaying clubs with most top scorers:
sa['Club 1'].value_counts().plot(kind = 'barh', color = 'cyan', figsize = (8, 6))
plt.ylabel(None)
plt.title('Clubs with most top scorers', fontweight = 'bold')
plt.show()

# %%
# Displaying the attendances by year:
plt.figure(figsize = (8, 4))
plt.title('Top scorer amount of goals by season', fontweight = 'bold')
plt.plot(sa['Season'], sa['Number of goals 1'], color = 'cyan')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-09e15723e93d> in <cell line: 4>()
#       2 plt.figure(figsize = (8, 4))
#       3 plt.title('Top scorer amount of goals by season', fontweight = 'bold')
# ----> 4 plt.plot(sa['Season'], sa['Number of goals 1'], color = 'cyan')
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...
